# %%
x = np.arange(-3, 3, 0.1)
y = np.tan(x)
plt.plot(x, y)
plt.show()

# %%
# !jupytext --to py --output ./jupytexts/Version_control.py ./Version_control.ipynb
# Out:
# [jupytext] Reading ./Version_control.ipynb
# [jupytext] Writing ./jupytexts/Version_control.py (destination file replaced)
